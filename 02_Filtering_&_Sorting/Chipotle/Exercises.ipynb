# %% [markdown]
# # Ex1 - Filtering and Sorting Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
chipo = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv',sep = '\t')
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# 5            3         1                           Chicken Bowl
# 6            3         1                          Side of Chips
# 7            4         1                          Steak Burrito
# 8            4         1                       Steak Soft Tacos
# 9            5         1                          Steak Burrito
# 10           5         1                    Chips and Guacamole
# 11           6         1                   Chicken Crispy Tacos
# 12           6         1                     Chicken Soft Tacos
# 13           7         1                           Chicken Bowl
# ...

# %% [markdown]
# ### Step 4. How many products cost more than $10.00?

# %%
money = lambda x:float(x[1:-1])
chipo.item_price = chipo.item_price.apply(money)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-12e9d790f9fd> in <module>()
#       1 money = lambda x:float(x[1:-1])
# ----> 2 chipo.item_price = chipo.item_price.apply(money)
#       3 chipo[chipo.item_price>10].shape()
#
# /Users/oreo/anaconda2/lib/python2.7/site-packages/pandas/core/series.pyc in apply(self, func, convert_dtype, args, **kwds)
#    2353             else:
#    2354                 values = self.asobject
# -> 2355                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2356
#    2357         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-9-12e9d790f9fd> in <lambda>(x)
# ----> 1 money = lambda x:float(x[1:-1])
#       2 chipo.item_price = chipo.item_price.apply(money)
#       3 chipo[chipo.item_price>10].shape()
#
# ...

# %%
chipo[chipo.item_price>10].shape[0]
# Out:
# 1130

# %% [markdown]
# ### Step 5. What is the price of each item?
# ###### print a data frame with only two columns item_name and item_price

# %%
chipo_du = chipo.drop_duplicates(['item_name','quantity'])
chipo_du = chipo_du[chipo_du.quantity == 1]
chipo_du = chipo_du.loc[:,('item_name','item_price')]

# %% [markdown]
# ### Step 6. Sort by the name of the item

# %%
chipo_du.sort_values('item_name')
# Out:
#                                   item_name  item_price
# 298                       6 Pack Soft Drink        6.49
# 39                            Barbacoa Bowl       11.75
# 21                         Barbacoa Burrito        8.99
# 168                   Barbacoa Crispy Tacos       11.75
# 1229                    Barbacoa Salad Bowl       11.89
# 56                      Barbacoa Soft Tacos        9.25
# 34                            Bottled Water        1.09
# 673                                    Bowl        7.40
# 510                                 Burrito        7.40
# 28                              Canned Soda        1.09
# 263                       Canned Soft Drink        1.25
# 33                            Carnitas Bowl        8.99
# 27                         Carnitas Burrito        8.99
# 554                   Carnitas Crispy Tacos        9.25
# 3750                         Carnitas Salad        8.99
# 1132                    Carnitas Salad Bowl       11.89
# ...

# %% [markdown]
# ### Step 7. What was the quantity of the most expensive item ordered?

# %%
chipo[chipo.item_price == max(chipo.item_price)].quantity
# Out:
# 3598    15
# Name: quantity, dtype: int64

# %% [markdown]
# ### Step 8. How many times were a Veggie Salad Bowl ordered?

# %%
len(chipo[chipo.item_name =='Veggie Salad Bowl'])
# Out:
# 18

# %% [markdown]
# ### Step 9. How many times people orderd more than one Canned Soda?

# %%
temp = chipo[chipo.item_name == 'Canned Soda']
temp[temp.quantity>1].count()
# Out:
# order_id              20
# quantity              20
# item_name             20
# choice_description    20
# item_price            20
# dtype: int64
